# %%
from math import sqrt
import random
import pandas as pd

# %%
data = pd.read_csv('/content/Sapfile1.arff', sep=",")
data
# Out:
#      F     G  Good Good.1    Vg  ...     Poor     Govt  Asm    Small   Good.3
# 0    M   OBC    Vg     Vg    Vg  ...     Poor     Govt  Asm  Average  Average
# 1    F   OBC  Good   Good    Vg  ...  Average     Govt  Asm    Large     Good
# 2    M  MOBC  Pass   Good    Vg  ...     Poor     Govt  Asm  Average  Average
# 3    M     G  Good   Good    Vg  ...     Poor  Private  Asm    Small     Good
# 4    M   OBC    Vg   Good    Vg  ...     Poor  Private  Eng  Average  Average
# ..  ..   ...   ...    ...   ...  ...      ...      ...  ...      ...      ...
# 125  M     G  Pass   Good  Good  ...  Average     Govt  Asm    Small     Poor
# 126  M  MOBC    Vg     Vg  Good  ...     Poor     Govt  Asm    Small  Average
# 127  F   OBC  Good   Good    Vg  ...  Average     Govt  Asm    Large     Good
# 128  M    ST  Pass   Pass  Good  ...  Average     Govt  Asm    Large  Average
# 129  M     G  Pass   Good  Good  ...  Average     Govt  Asm    Small  Average
#
# [130 rows x 22 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(data[:9] , test_size=0.33)

# %%
 kmeans = KMeans(
   init="random",
   n_clusters=3,
   n_init=10,
   max_iter=300,
   random_state=42
  )

# %%
k = kmeans.fit(X_test)

# %%
kmeans.cluster_centers_
